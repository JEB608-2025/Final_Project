# %% [markdown]
# Fire Trainer
# Here is where we will be discovering where the best neighborhood is for a fire type pokemon trainer would like to live.
# Let's first transport the dataset that I have chosen to use.

# %%
import pandas as pd
fire_df = pd.read_csv("fireincidents.csv")
fire_df.head()
# Out:
#    _id     call_no  incident_type        type_description  \
# 0    1  F160029985          111.0           Building fire
# 1    2  F180022058          111.0           Building fire
# 2    3  F180022102          131.0  Passenger vehicle fire
# 3    4  F170043431          131.0  Passenger vehicle fire
# 4    5  F180021111          111.0           Building fire
#
#                                           address  alarms  \
# 0       800 BLOCK CENTER ST, WILKINSBURG PA 15221       1
# 1        1100 BLOCK JANE ST, WILKINSBURG PA 15221       1
# 2  SB STATE HWY 28 SB AT 31S, PITTSBURGH PA 15212       0
# 3      1700 BLOCK BELLEAU DR, PITTSBURGH PA 15212       0
# 4      2400 BLOCK VILLAGE RD, PITTSBURGH PA 15205       1
#
#             alarm_time primary_unit  census_tract neighborhood  \
# 0  2016-04-21T05:01:04      231EN16           NaN          NaN
# 1  2018-03-13T08:34:43      231EN16           NaN          NaN
# 2  2018-03-13T11:54:23      231EN32        2406.0          NaN
# ...

# %% [markdown]
# Now that we have printed out the data, let's clean it up a little bit to only show the more important data.

# %%
filteredfires = fire_df[["neighborhood", "type_description", "alarms", "ward"]]
filteredfires = filteredfires.dropna()
print(filteredfires.head())
# Out:
#                neighborhood                     type_description  alarms  ward
# 3                  Fineview               Passenger vehicle fire       0  25.0
# 4                 Fairywood                        Building fire       1  28.0
# 5          South Side Flats          Outside rubbish fire, Other       0  17.0
# 6          Allegheny Center  Cooking fire, confined to container       1  22.0
# 7  Lincoln-Lemington-Belmar                        Building fire       1  12.0

# %% [markdown]
# I have no idea why it is so small but this is basically everything that we need to truly deduct what is the best neighborhood for a fire pokemon trainer. We have the exact neighborhood on the far left. We have the type of fire incidents next of it, then we have the number of alarms around that area and the ward is just the general area of where the fire started.
